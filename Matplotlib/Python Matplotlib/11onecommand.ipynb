# %%
'''
@Author: Rashmi
@Date: 2021-10-6 23:05
@Last Modified by: Rashmi
@Last Modified time: 2021-10-6 23:22
@Title : ​ Write a Python program to plot several lines with different format styles in one command
using arrays.
'''
import matplotlib.pyplot as plt 
import numpy as np

x=np.array([1,2,3,4,5])
plt.plot(x,x*10,'bs',x,x*50,'c<',x,x*100,'r^')   #using plot

plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("quantities printing for arrays of different styles")
plt.show()

# # Sampled time at 200ms intervals
# t = np.arange(0., 5., 0.2)
# plt.plot(t, t, 'g--', t, t**2, 'bs', t, t**3, 'r^')
# plt.show()
