# %%
'''
@Author: Rashmi
@Date: 2021-10-8 24:08
@Last Modified by: Rashmi
@Last Modified time: 2021-10-8 24:26
@Title :Write a Python program to draw a scatter plot for three different groups camparing weights
and heights.
'''
import matplotlib.pyplot as plt
import numpy as np 
weight1=[67,57.2,59.6,59.64,55.8,61.2,60.45,61,56.23,56]
height1=[101.7,197.6,98.3,125.1,113.7,157.7,136,148.9,125.3,114.9] 
height2=[152.8,155.3,135.1,125.2,151.3,135,182.2,195.9,165.1,125.1] 
height3=[165.8,170.9,192.8,135.4,161.4,136.1,167.1,235.1,181.1,177.3]
plt.scatter(weight1, height1,color='r',marker='+')
plt.scatter(weight1, height2,color='b',marker='s')
plt.scatter(weight1, height3,color='c',marker='>')
plt.xlabel('weight', fontsize=16)
plt.ylabel('height', fontsize=16)
plt.title('Group wise Weight vs Height scatter plot',fontsize=20)
plt.show()
