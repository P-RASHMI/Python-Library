# %%
'''
@Author: Rashmi
@Date: 2021-10-7 18:40
@Last Modified by: Rashmi
@Last Modified time: 2021-10-7 18:50
@Title :Write a Python programming to display a bar chart of the popularity of programming
Languages. Select the width of each bar and their positions.
Sample data:
Programming languages: Java, Python, PHP, JavaScript, C#, C++
Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
'''
import matplotlib.pyplot as plt
import numpy as np

pgm_lang = ['Java','Python','PHP','JavaScript','C#','C++']
Popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
xpos = np.arange(len(pgm_lang)) #xpos is array 
plt.xticks(xpos,pgm_lang)
plt.xlabel("programming langs")
plt.ylabel("Popularity")
plt.title("bar chart of the popularity of programming Languages specific positins of bars")
width = [0.1,1.2,0.5,1.1,1.5,0.3] #width for each bar
y_pos = [1,3,6,8,10,11]  #number for positions 2,4,7,9,11,12(y_pos = indexes )
plt.bar(y_pos,Popularity,color =['cyan','yellow','green','orange','red','blue'],width = width)
plt.xticks(y_pos,pgm_lang) #again changing values names to the given ypos
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
